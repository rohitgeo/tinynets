# %% [markdown]
# ## Setup

# %%
# !git clone https://github.com/fastai/course22p2
# %cd course22p2
# !pip install -e .
# Out:
# d:\github\course22p2\course22p2
# Cloning into 'course22p2'...
# Obtaining file:///D:/github/course22p2/course22p2
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from miniai==0.0.1) (3.6.2)
# Requirement already satisfied: datasets in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from miniai==0.0.1) (2.8.0)
# Requirement already satisfied: fastprogress in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from miniai==0.0.1) (1.0.3)
# Requirement already satisfied: fastcore in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from miniai==0.0.1) (1.5.27)
# Requirement already satisfied: torch<1.14,>=1.7 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from miniai==0.0.1) (1.13.0)
# Requirement already satisfied: torcheval in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from miniai==0.0.1) (0.0.5)
# Requirement already satisfied: diffusers in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from miniai==0.0.1) (0.6.0)
# Requirement already satisfied: einops in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from miniai==0.0.1) (0.3.0)
# Requirement already satisfied: timm in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from miniai==0.0.1) (0.6.12)
# Requirement already satisfied: typing_extensions in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from torch<1.14,>=1.7->miniai==0.0.1) (4.3.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from datasets->miniai==0.0.1) (0.10.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from datasets->miniai==0.0.1) (6.0)
# Requirement already satisfied: requests>=2.19.0 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from datasets->miniai==0.0.1) (2.25.1)
# Requirement already satisfied: multiprocess in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from datasets->miniai==0.0.1) (0.70.14)
# Requirement already satisfied: tqdm>=4.62.1 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from datasets->miniai==0.0.1) (4.64.1)
# Requirement already satisfied: xxhash in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from datasets->miniai==0.0.1) (3.2.0)
# Requirement already satisfied: pyarrow>=6.0.0 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from datasets->miniai==0.0.1) (10.0.0)
# Requirement already satisfied: aiohttp in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from datasets->miniai==0.0.1) (3.8.3)
# Requirement already satisfied: dill<0.3.7 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from datasets->miniai==0.0.1) (0.3.6)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from datasets->miniai==0.0.1) (22.0)
# Requirement already satisfied: responses<0.19 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from datasets->miniai==0.0.1) (0.18.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from datasets->miniai==0.0.1) (2022.10.0)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from datasets->miniai==0.0.1) (1.5.1)
# Requirement already satisfied: numpy>=1.17 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from datasets->miniai==0.0.1) (1.23.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from diffusers->miniai==0.0.1) (2022.10.31)
# Requirement already satisfied: Pillow<10.0 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from diffusers->miniai==0.0.1) (9.2.0)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from diffusers->miniai==0.0.1) (3.8.0)
# Requirement already satisfied: importlib-metadata in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from diffusers->miniai==0.0.1) (5.0.0)
# Requirement already satisfied: pip in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from fastcore->miniai==0.0.1) (22.2.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from matplotlib->miniai==0.0.1) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from matplotlib->miniai==0.0.1) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from matplotlib->miniai==0.0.1) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from matplotlib->miniai==0.0.1) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from matplotlib->miniai==0.0.1) (4.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from matplotlib->miniai==0.0.1) (1.0.6)
# Requirement already satisfied: torchvision in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from timm->miniai==0.0.1) (0.14.0)
# Requirement already satisfied: torchtnt in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from torcheval->miniai==0.0.1) (0.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from aiohttp->datasets->miniai==0.0.1) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from aiohttp->datasets->miniai==0.0.1) (2.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from aiohttp->datasets->miniai==0.0.1) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from aiohttp->datasets->miniai==0.0.1) (1.8.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from aiohttp->datasets->miniai==0.0.1) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from aiohttp->datasets->miniai==0.0.1) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from aiohttp->datasets->miniai==0.0.1) (6.0.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from python-dateutil>=2.7->matplotlib->miniai==0.0.1) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from requests>=2.19.0->datasets->miniai==0.0.1) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from requests>=2.19.0->datasets->miniai==0.0.1) (1.26.12)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from requests>=2.19.0->datasets->miniai==0.0.1) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from requests>=2.19.0->datasets->miniai==0.0.1) (4.0.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from tqdm>=4.62.1->datasets->miniai==0.0.1) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from importlib-metadata->diffusers->miniai==0.0.1) (3.10.0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from pandas->datasets->miniai==0.0.1) (2022.7)
# Requirement already satisfied: tensorboard in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from torchtnt->torcheval->miniai==0.0.1) (2.10.1)
# Requirement already satisfied: psutil in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from torchtnt->torcheval->miniai==0.0.1) (5.9.3)
# Requirement already satisfied: pyre-extensions in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from torchtnt->torcheval->miniai==0.0.1) (0.0.30)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from torchtnt->torcheval->miniai==0.0.1) (65.5.0)
# Requirement already satisfied: typing-inspect in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from pyre-extensions->torchtnt->torcheval->miniai==0.0.1) (0.8.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from tensorboard->torchtnt->torcheval->miniai==0.0.1) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from tensorboard->torchtnt->torcheval->miniai==0.0.1) (0.4.6)
# Requirement already satisfied: grpcio>=1.24.3 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from tensorboard->torchtnt->torcheval->miniai==0.0.1) (1.50.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from tensorboard->torchtnt->torcheval->miniai==0.0.1) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from tensorboard->torchtnt->torcheval->miniai==0.0.1) (2.14.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from tensorboard->torchtnt->torcheval->miniai==0.0.1) (3.4.1)
# Requirement already satisfied: wheel>=0.26 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from tensorboard->torchtnt->torcheval->miniai==0.0.1) (0.37.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from tensorboard->torchtnt->torcheval->miniai==0.0.1) (3.19.6)
# Requirement already satisfied: absl-py>=0.4 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from tensorboard->torchtnt->torcheval->miniai==0.0.1) (1.3.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from tensorboard->torchtnt->torcheval->miniai==0.0.1) (2.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->torchtnt->torcheval->miniai==0.0.1) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->torchtnt->torcheval->miniai==0.0.1) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->torchtnt->torcheval->miniai==0.0.1) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->torchtnt->torcheval->miniai==0.0.1) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from werkzeug>=1.0.1->tensorboard->torchtnt->torcheval->miniai==0.0.1) (2.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from typing-inspect->pyre-extensions->torchtnt->torcheval->miniai==0.0.1) (0.4.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->torchtnt->torcheval->miniai==0.0.1) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\programdata\anaconda3\envs\invokeai\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->torchtnt->torcheval->miniai==0.0.1) (3.2.2)
# Installing collected packages: miniai
#   Attempting uninstall: miniai
#     Found existing installation: miniai 0.0.1
#     Uninstalling miniai-0.0.1:
#       Successfully uninstalled miniai-0.0.1
#   Running setup.py develop for miniai
# Successfully installed miniai-0.0.1

# %% [markdown]
# ## Custom Sampler

# %%
import pickle,gzip,math,os,time,shutil,torch,random
import fastcore.all as fc,matplotlib as mpl,numpy as np,matplotlib.pyplot as plt
from collections.abc import Mapping
from pathlib import Path
from operator import attrgetter,itemgetter
from functools import partial
from copy import copy
from contextlib import contextmanager

import torchvision.transforms.functional as TF,torch.nn.functional as F
from torch import tensor,nn,optim
from torch.utils.data import DataLoader,default_collate
from torch.nn import init
from torch.optim import lr_scheduler
from torcheval.metrics import MulticlassAccuracy
from datasets import load_dataset,load_dataset_builder

from miniai.datasets import *
from miniai.conv import *
from miniai.learner import *
from miniai.activations import *
from miniai.init import *
from miniai.sgd import *
from miniai.resnet import *

# %%
from fastcore.test import test_close
from torch import distributions

torch.set_printoptions(precision=2, linewidth=140, sci_mode=False)
torch.manual_seed(1)
mpl.rcParams['image.cmap'] = 'gray'

import logging
logging.disable(logging.WARNING)

set_seed(15)

if fc.defaults.cpus>8: fc.defaults.cpus=8

# %%
xl,yl = 'image','label'
name = "mnist"
bs = 256 # 1024
xmean,xstd = 0.28, 0.35

@inplace
def transformi(b): b[xl] = [(TF.to_tensor(o)-xmean)/xstd for o in b[xl]]

dsd = load_dataset(name)
tds = dsd.with_transform(transformi)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
from typing import Iterator
from torch.utils.data import DataLoader, WeightedRandomSampler

# %%
class TopLossesCallback(Callback):
  epoch_preds = []
  epoch_targets = []
  
  @torch.no_grad()
  def _calculate_top_losses(self):
    preds = torch.cat(self.epoch_preds, dim=0)
    targets = torch.cat(self.epoch_targets, dim=0)
    losses = F.cross_entropy(preds, targets, reduce=False)
    return torch.topk(losses, preds.shape[0]).indices

  def after_batch(self, learn):
    if not learn.model.training:
      return
    self.epoch_preds.append(learn.preds)
    self.epoch_targets.append(learn.batch[1])

  def before_epoch(self, learn):
    self.epoch_preds = []
    self.epoch_targets = []

  def after_epoch(self, learn):
    if not learn.model.training:
      return
    learn.dls.train.sampler.top_losses = self._calculate_top_losses()


class CustomTrainingSampler(WeightedRandomSampler):
  def __init__(self, *args, **kwargs):
    WeightedRandomSampler.__init__(self, *args, **kwargs)
    self.data_indexes_for_epoch = []
    self.top_losses = []
    self.epoch = -1
    self.n = {
        0: 0,
        1: 0,
        # Before the 2nd epoch drop 10% of the training dataset with the lowest losses.
        # Replace them with the 10% of the training dataset with the highest losses.
        # This gives the model two opportunities to train on the most challenging images.
        2: 0.10,
        3: 0,
        4: 0,
        5: 0,
        6: 0
    }

  def __iter__(self) -> Iterator[int]:
    self.epoch += 1
    rand_tensor = torch.randperm(self.num_samples, generator=self.generator).tolist()
    try:
      n = int(self.n[self.epoch] * self.num_samples)

      if n != 0:
        # TODO: Cleanup the code below
        inverted_losses_for_epochs = torch.flip(torch.tensor(self.top_losses.clone().detach()[:n]), dims=(0,)).cpu()
        self.data_indexes_for_epoch = torch.tensor(self.data_indexes_for_epoch).cpu()
        self.data_indexes_for_epoch[self.top_losses[-n:].cpu()] = self.data_indexes_for_epoch[inverted_losses_for_epochs]
        self.data_indexes_for_epoch = self.data_indexes_for_epoch[rand_tensor]
        self.data_indexes_for_epoch = self.data_indexes_for_epoch.tolist()
      else:
        self.data_indexes_for_epoch = rand_tensor
    except:
      self.data_indexes_for_epoch = rand_tensor

    yield from self.data_indexes_for_epoch


class CustomDataLoader:
    def __init__(self, *dls): 
      self.train,self.valid = dls[:2]

    def get_sampler(num_samples, mode="train"):
      if mode != "train":
        return None
      return CustomTrainingSampler(weights=[1 for _ in range(num_samples)], num_samples=num_samples)

    @classmethod
    def from_dd(cls, dd, batch_size, as_tuple=True, **kwargs):
      return cls(*[DataLoader(ds, batch_size, sampler=cls.get_sampler(len(ds), mode), collate_fn=collate_dict(ds), **kwargs) for mode, ds in dd.items()])

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F  #(uncomment if needed,but you likely already have it)

#Mish - "Mish: A Self Regularized Non-Monotonic Neural Activation Function"
#https://arxiv.org/abs/1908.08681v1
#implemented for PyTorch / FastAI by lessw2020 
#github: https://github.com/lessw2020/mish

class Mish(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, x):
        #inlining this saves 1 second per epoch (V100 GPU) vs having a temp x and then returning x(!)
        return x *( torch.tanh(F.softplus(x)))

# %%
def _rand_erase1(x, pct, xm, xs, mn, mx):
    szx = int(pct*x.shape[-2])
    szy = int(pct*x.shape[-1])
    stx = int(random.random()*(1-pct)*x.shape[-2])
    sty = int(random.random()*(1-pct)*x.shape[-1])
    init.normal_(x[:,:,stx:stx+szx,sty:sty+szy], mean=xm, std=xs)
    x.clamp_(mn, mx)
    
def rand_erase(x, pct=0.2, max_num = 4):
    xm,xs,mn,mx = x.mean(),x.std(),x.min(),x.max()
    num = random.randint(0, max_num)
    for i in range(num): _rand_erase1(x, pct, xm, xs, mn, mx)
#     print(num)
    return x

class RandomErase(nn.Module):
    def __init__(self, pct=0.2, max_num=4):
        super().__init__()
        self.pct,self.max_num = pct,max_num
    def forward(self, x): return rand_erase(x, self.pct, self.max_num)

# %%
act = Mish
nfs = (16, 32, 64, 128, 256, 512)
norm = nn.BatchNorm2d
layers = [ResBlock(1, 16, ks=5, stride=1, act=act, norm=norm)]
layers += [ResBlock(nfs[i], nfs[i+1], act=act, norm=norm, stride=2) for i in range(len(nfs)-1)]
layers += [nn.Flatten(), nn.Linear(nfs[-1], 10, bias=False), nn.BatchNorm1d(10)]

layers
# Out:
# [ResBlock(
#    (convs): Sequential(
#      (0): Sequential(
#        (0): Conv2d(1, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#        (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (2): Mish()
#      )
#      (1): Sequential(
#        (0): Conv2d(16, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#        (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (idconv): Sequential(
#      (0): Conv2d(1, 16, kernel_size=(1, 1), stride=(1, 1))
#    )
#    (act): Mish()
#  ),
#  ResBlock(
#    (convs): Sequential(
#      (0): Sequential(
#        (0): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (2): Mish()
#      )
#      (1): Sequential(
#        (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (idconv): Sequential(
#      (0): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#    )
#    (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#    (act): Mish()
#  ),
#  ResBlock(
#    (convs): Sequential(
#      (0): Sequential(
#        (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (2): Mish()
#      )
#      (1): Sequential(
#        (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (idconv): Sequential(
#      (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#    )
#    (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#    (act): Mish()
#  ),
#  ResBlock(
#    (convs): Sequential(
#      (0): Sequential(
#        (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (2): Mish()
#      )
#      (1): Sequential(
#        (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (idconv): Sequential(
#      (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#    )
#    (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#    (act): Mish()
#  ),
#  ResBlock(
#    (convs): Sequential(
#      (0): Sequential(
#        (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (2): Mish()
#      )
#      (1): Sequential(
#        (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (idconv): Sequential(
#      (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#    )
#    (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#    (act): Mish()
#  ),
#  ResBlock(
#    (convs): Sequential(
#      (0): Sequential(
#        (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (2): Mish()
#      )
#      (1): Sequential(
#        (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (idconv): Sequential(
#      (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#    )
#    (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#    (act): Mish()
#  ),
#  Flatten(start_dim=1, end_dim=-1),
#  Linear(in_features=512, out_features=10, bias=False),
#  BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)]

# %%
def get_model(act=Mish, nfs=(16,32,64,128,256,512), norm=nn.BatchNorm2d):
    layers = [ResBlock(1, 16, ks=5, stride=1, act=act, norm=norm)]
    layers += [ResBlock(nfs[i], nfs[i+1], act=act, norm=norm, stride=2) for i in range(len(nfs)-1)]
    layers += [nn.Flatten(), nn.Linear(nfs[-1], 10, bias=False), nn.BatchNorm1d(10)]
    
    return nn.Sequential(*layers)

# %%
def get_model_dropout(act=Mish, nfs=(16,32,64,128,256,512), norm=nn.BatchNorm2d):
    layers = [ResBlock(1, 16, ks=5, stride=1, act=act, norm=norm)]
    layers += [ResBlock(nfs[i], nfs[i+1], act=act, norm=norm, stride=2) for i in range(len(nfs)-1)]
    layers += [nn.Dropout2d(0.1), nn.Flatten(), nn.Linear(nfs[-1], 10, bias=False), nn.BatchNorm1d(10)]
    
    return nn.Sequential(*layers)

# %%
def get_model2_dropout(act=Mish, nfs=(16,32,64,128,256,512, 1024), norm=nn.BatchNorm2d):
    layers = [ResBlock(1, 16, ks=5, stride=1, act=act, norm=norm)]
    layers += [ResBlock(nfs[i], nfs[i+1], act=act, norm=norm, stride=2) for i in range(len(nfs)-1)]
    layers += [nn.Dropout2d(0.1), nn.Flatten(), nn.Linear(nfs[-1], 10, bias=False), nn.BatchNorm1d(10)]
    
    return nn.Sequential(*layers)

# %%
def get_model_dropout2(act=Mish, nfs=(16,32,64,128,256,512), norm=nn.BatchNorm2d):
    layers = [ResBlock(1, 16, ks=5, stride=1, act=act, norm=norm)]
    layers += [ResBlock(nfs[i], nfs[i+1], act=act, norm=norm, stride=2) for i in range(len(nfs)-2)]
    layers += [nn.Dropout2d(0.1), ResBlock(nfs[4], nfs[4+1], act=act, norm=norm, stride=2)]
    layers += [nn.Dropout2d(0.1), nn.Flatten(), nn.Linear(nfs[-1], 10, bias=False), nn.BatchNorm1d(10)]
    
    return nn.Sequential(*layers)

# %%
def get_model_dropout_mish(act=Mish, nfs=(16,32,64,128,256,512), norm=nn.BatchNorm2d):
    layers = [ResBlock(1, 16, ks=5, stride=1, act=act, norm=norm)]
    layers += [ResBlock(nfs[i], nfs[i+1], act=act, norm=norm, stride=2) for i in range(len(nfs)-1)]
    layers += [nn.Dropout2d(0.2), nn.Flatten(), nn.Linear(nfs[-1], 10, bias=False), nn.BatchNorm1d(10)]
    return nn.Sequential(*layers)

# %%
def get_model_relu(act=nn.ReLU, nfs=(16,32,64,128,256,512), norm=nn.BatchNorm2d):
    layers = [ResBlock(1, 16, ks=5, stride=1, act=act, norm=norm)]
    layers += [ResBlock(nfs[i], nfs[i+1], act=act, norm=norm, stride=2) for i in range(len(nfs)-1)]
    layers += [nn.Flatten(), nn.Linear(nfs[-1], 10, bias=False), nn.BatchNorm1d(10)]
    return nn.Sequential(*layers)

# %%
from torchvision import transforms

def tfm_batch(b, tfm_x=fc.noop, tfm_y = fc.noop): return tfm_x(b[0]),tfm_y(b[1])

tfms = nn.Sequential(transforms.RandomCrop(28, padding=1),
                     transforms.RandomHorizontalFlip(),
                     RandomErase()                     
                    )
augcb = BatchTransformCB(partial(tfm_batch, tfm_x=tfms), on_val=False)

# %%
def init_ortho_weights(m):
    if isinstance(m, (nn.Conv1d,nn.Conv2d,nn.Conv3d)): init.orthogonal_(m.weight)

# %% [markdown]
# ### MixUp

# %%
def randchoice(t, squeeze=False, n=1): 
    if squeeze:
        return t[torch.randperm(n)].squeeze()
    else:
        return t[torch.randperm(n)]
    
def getMixupIndicies(y):
    bs = y.shape[0]
    left = torch.arange(0,bs-1)
    right = randchoice(left, n=left.size()[0])
    right = [r if y[l] != y[r] else randchoice(y[y != y[l]].nonzero(), True) for l,r in zip(left,right)]
    return left, tensor(right)

class MixUp(Callback):
    def __init__(self, pct=0.2): self.pct = pct
    def before_batch(self, learn):
        if learn.model.training:
            xb, yb = learn.batch
            l,r = getMixupIndicies(yb)
            xb = xb[l]*(1-self.pct) + xb[r]*self.pct
            yb = F.one_hot(yb[l])*(1-self.pct) + F.one_hot(yb[r])*self.pct
            learn.batch = xb, yb
    def after_batch(self, learn):
        if learn.model.training:
            xb, yb = learn.batch
            yb = yb.argmax(1)
            learn.batch = xb, yb

# %%
dls = CustomDataLoader.from_dd(tds, bs, num_workers=0)

# %%
set_seed(42)
lr = 1e-2
epochs = 5
metrics = MetricsCB(accuracy=MulticlassAccuracy())
astats = ActivationStats(fc.risinstance(GeneralRelu))
cbs = [DeviceCB(), metrics, TopLossesCallback(), ProgressCB(plot=True), astats]
tmax = epochs * len(dls.train)
sched = partial(lr_scheduler.OneCycleLR, max_lr=lr, total_steps=tmax)
xtra = [BatchSchedCB(sched)] #, augcb]
act_gr = partial(Mish) #GeneralRelu, leak=0.1, sub=0.4)
# act_gr = partial(GeneralRelu, leak=0.1, sub=0.4)
iw = partial(init_weights, leaky=0.1) # init_ortho_weights
# model = get_model_dropout_mish(act_gr, norm=nn.BatchNorm2d).apply(iw)
# model = get_model(act_gr, norm=nn.BatchNorm2d).apply(iw)
# model = get_model_dropout(act_gr, norm=nn.BatchNorm2d).apply(iw)
model = get_model_dropout(act_gr, norm=nn.BatchNorm2d).apply(iw)

# %%
from torchvision import transforms

def tfm_batch(b, tfm_x=fc.noop, tfm_y = fc.noop): return tfm_x(b[0]),tfm_y(b[1])

tfms = nn.Sequential(transforms.RandomCrop(28, padding=1),
                     transforms.RandomRotation(30)       
                    )
augcb = BatchTransformCB(partial(tfm_batch, tfm_x=tfms), on_val=False)

# %%
learn = TrainLearner(model, dls, F.cross_entropy, lr=lr, cbs=[MixUp(0.05)]+cbs+xtra+[augcb], opt_func=optim.AdamW)

# bs 256 + Mish + lr3e-2 + dropouts + aug 5 epochs + MixUp + rotation aug
learn.fit(epochs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.924</td>
#       <td>0.626</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.971</td>
#       <td>0.202</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.975</td>
#       <td>0.388</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.985</td>
#       <td>0.104</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.984</td>
#       <td>0.358</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.991</td>
#       <td>0.077</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.990</td>
#       <td>0.339</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.994</td>
#       <td>0.071</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.993</td>
#       <td>0.329</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.995</td>
#       <td>0.067</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\rohit\AppData\Local\Temp\ipykernel_31708\2428293066.py:55: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   inverted_losses_for_epochs = torch.flip(torch.tensor(self.top_losses.clone().detach()[:n]), dims=(0,)).cpu()

# %%
learn = TrainLearner(model, dls, F.cross_entropy, lr=lr, cbs=[MixUp(0.05)]+cbs+xtra, opt_func=optim.AdamW)

# bs 256 + Mish + lr3e-2 + dropouts + aug 5 epochs + MixUp
learn.fit(epochs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.965</td>
#       <td>0.516</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.972</td>
#       <td>0.178</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.984</td>
#       <td>0.362</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.985</td>
#       <td>0.107</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.992</td>
#       <td>0.336</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.994</td>
#       <td>0.070</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.997</td>
#       <td>0.322</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.995</td>
#       <td>0.065</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.999</td>
#       <td>0.315</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.995</td>
#       <td>0.063</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\rohit\AppData\Local\Temp\ipykernel_31708\2428293066.py:55: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   inverted_losses_for_epochs = torch.flip(torch.tensor(self.top_losses.clone().detach()[:n]), dims=(0,)).cpu()

# %%
learn = TrainLearner(model, dls, F.cross_entropy, lr=lr, cbs=[MixUp(0.05)]+cbs+xtra, opt_func=optim.AdamW)

# bs 256 + Mish + lr3e-2 + dropouts + aug 5 epochs + MixUp(0.1)
learn.fit(epochs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.964</td>
#       <td>0.694</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.984</td>
#       <td>0.164</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.984</td>
#       <td>0.563</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.983</td>
#       <td>0.148</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.988</td>
#       <td>0.483</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.989</td>
#       <td>0.143</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.994</td>
#       <td>0.425</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.994</td>
#       <td>0.100</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.997</td>
#       <td>0.398</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.994</td>
#       <td>0.091</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\rohit\AppData\Local\Temp\ipykernel_31708\2428293066.py:55: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   inverted_losses_for_epochs = torch.flip(torch.tensor(self.top_losses.clone().detach()[:n]), dims=(0,)).cpu()

# %%
learn = TrainLearner(model, dls, F.cross_entropy, lr=lr, cbs=[MixUp(0.1)]+cbs+xtra, opt_func=optim.AdamW)

# bs 64 + Mish + lr3e-2 + dropouts + aug 5 epochs 
learn.fit(epochs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       60.00% [3/5 03:25&lt;02:16]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.992</td>
#       <td>0.418</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.981</td>
#       <td>0.126</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.987</td>
#       <td>0.429</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.988</td>
#       <td>0.083</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.993</td>
#       <td>0.394</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.991</td>
#       <td>0.072</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='198' class='' max='235' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       84.26% [198/235 00:53&lt;00:10 0.360]
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[206], line 4
#       1 learn = TrainLearner(model, dls, F.cross_entropy, lr=lr, cbs=[MixUp(0.1)]+cbs+xtra, opt_func=optim.AdamW)
#       3 # bs 64 + Mish + lr3e-2 + dropouts + aug 5 epochs
# ----> 4 learn.fit(epochs)
#
# File d:\github\course22p2\miniai\learner.py:126, in Learner.fit(self, n_epochs, train, valid, cbs, lr)
#     124     with self.cb_ctx('fit'):
#     125         for self.epoch in self.epochs:
# --> 126             if train: self.one_epoch(True)
#     127             if valid: torch.no_grad()(self.one_epoch)(False)
#     128 finally:
#
# File d:\github\course22p2\miniai\learner.py:108, in Learner.one_epoch(self, train)
#     106 with self.cb_ctx('epoch'):
#     107     for self.iter,self.batch in enumerate(self.dl):
# --> 108         with self.cb_ctx('batch'):
#     109             self.predict()
#     110             self.get_loss()
#
# File d:\github\course22p2\miniai\learner.py:227, in callback_ctx.__exit__(self, exc_type, exc_val, traceback)
#     225 chk_exc = globals()[f'Cancel{self.nm.title()}Exception']
#     226 try:
# --> 227     if not exc_type: self.cbmeth(f'after_{self.nm}')
#     228     return exc_type==chk_exc
#     229 except chk_exc: pass
#
# File d:\github\course22p2\miniai\learner.py:135, in Learner.callback(self, method_nm)
# --> 135 def callback(self, method_nm): run_cbs(self.cbs, method_nm, self)
#
# File d:\github\course22p2\miniai\learner.py:50, in run_cbs(cbs, method_nm, learn)
#      48 for cb in sorted(cbs, key=attrgetter('order')):
#      49     method = getattr(cb, method_nm, None)
# ---> 50     if method is not None: method(learn)
#
# File d:\github\course22p2\miniai\learner.py:169, in ProgressCB.after_batch(self, learn)
#     167 if self.plot and hasattr(learn, 'metrics') and learn.training:
#     168     self.losses.append(learn.loss.item())
# --> 169     self.mbar.update_graph([[fc.L.range(self.losses), self.losses]])
#
# File C:\ProgramData\Anaconda3\envs\invokeai\lib\site-packages\fastprogress\fastprogress.py:204, in NBMasterBar.update_graph(self, graphs, x_bounds, y_bounds, figsize)
#     202 self.graph_ax.clear()
#     203 if len(self.names) < len(graphs): self.names += [''] * (len(graphs) - len(self.names))
# --> 204 for g,n in zip(graphs,self.names): self.graph_ax.plot(*g, label=n)
#     205 self.graph_ax.legend(loc='upper right')
#     206 if x_bounds is not None: self.graph_ax.set_xlim(*x_bounds)
#
# File C:\ProgramData\Anaconda3\envs\invokeai\lib\site-packages\matplotlib\axes\_axes.py:1664, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1662 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1663 for line in lines:
# -> 1664     self.add_line(line)
#    1665 if scalex:
#    1666     self._request_autoscale_view("x")
#
# File C:\ProgramData\Anaconda3\envs\invokeai\lib\site-packages\matplotlib\axes\_base.py:2340, in _AxesBase.add_line(self, line)
#    2337 if line.get_clip_path() is None:
#    2338     line.set_clip_path(self.patch)
# -> 2340 self._update_line_limits(line)
#    2341 if not line.get_label():
#    2342     line.set_label(f'_child{len(self._children)}')
#
# File C:\ProgramData\Anaconda3\envs\invokeai\lib\site-packages\matplotlib\axes\_base.py:2363, in _AxesBase._update_line_limits(self, line)
#    2359 def _update_line_limits(self, line):
#    2360     """
#    2361     Figures out the data limit of the given line, updating self.dataLim.
#    2362     """
# -> 2363     path = line.get_path()
#    2364     if path.vertices.size == 0:
#    2365         return
#
# File C:\ProgramData\Anaconda3\envs\invokeai\lib\site-packages\matplotlib\lines.py:1031, in Line2D.get_path(self)
#    1029 """Return the `~matplotlib.path.Path` associated with this line."""
#    1030 if self._invalidy or self._invalidx:
# -> 1031     self.recache()
#    1032 return self._path
#
# File C:\ProgramData\Anaconda3\envs\invokeai\lib\site-packages\matplotlib\lines.py:668, in Line2D.recache(self, always)
#     665 else:
#     666     y = self._y
# --> 668 self._xy = np.column_stack(np.broadcast_arrays(x, y)).astype(float)
#     669 self._x, self._y = self._xy.T  # views
#     671 self._subslice = False
#
# File <__array_function__ internals>:180, in column_stack(*args, **kwargs)
#
# File C:\ProgramData\Anaconda3\envs\invokeai\lib\site-packages\numpy\lib\shape_base.py:656, in column_stack(tup)
#     654         arr = array(arr, copy=False, subok=True, ndmin=2).T
#     655     arrays.append(arr)
# --> 656 return _nx.concatenate(arrays, 1)
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
learn = TrainLearner(model, dls, F.cross_entropy, lr=lr, cbs=cbs+xtra, opt_func=optim.AdamW)

# bs 256 + Mish + lr3e-2 + dropouts + aug 5 epochs 
learn.fit(epochs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.966</td>
#       <td>0.226</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.919</td>
#       <td>0.259</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.979</td>
#       <td>0.079</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.985</td>
#       <td>0.058</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.981</td>
#       <td>0.067</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.992</td>
#       <td>0.028</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.995</td>
#       <td>0.019</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.995</td>
#       <td>0.017</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.999</td>
#       <td>0.007</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.996</td>
#       <td>0.015</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\rohit\AppData\Local\Temp\ipykernel_31708\2428293066.py:55: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   inverted_losses_for_epochs = torch.flip(torch.tensor(self.top_losses.clone().detach()[:n]), dims=(0,)).cpu()

# %%
learn = TrainLearner(model, dls, F.cross_entropy, lr=lr, cbs=cbs+xtra, opt_func=optim.AdamW)

# bs 256 + Mish + lr3e-2 + dropouts + aug 5 epochs + orthogonal init

learn.fit(epochs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.966</td>
#       <td>0.256</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.969</td>
#       <td>0.130</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.982</td>
#       <td>0.074</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.989</td>
#       <td>0.045</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.990</td>
#       <td>0.040</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.985</td>
#       <td>0.052</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.994</td>
#       <td>0.023</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.995</td>
#       <td>0.019</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.998</td>
#       <td>0.010</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.995</td>
#       <td>0.017</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# C:\ProgramData\Anaconda3\envs\invokeai\lib\site-packages\torch\nn\_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))

# %%
learn = TrainLearner(model, dls, F.cross_entropy, lr=lr, cbs=cbs+xtra, opt_func=optim.AdamW)

# bs 256 + GeneralReLu + lr3e-2 + dropouts + aug 5 epochs

learn.fit(epochs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.967</td>
#       <td>0.260</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.973</td>
#       <td>0.101</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.981</td>
#       <td>0.074</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.985</td>
#       <td>0.059</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.989</td>
#       <td>0.041</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.990</td>
#       <td>0.037</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.994</td>
#       <td>0.024</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.995</td>
#       <td>0.017</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.998</td>
#       <td>0.010</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.996</td>
#       <td>0.015</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn = TrainLearner(model, dls, F.cross_entropy, lr=lr, cbs=cbs+xtra, opt_func=optim.AdamW)

# bs 256 + ReLU6 + lr3e-2 + dropouts + aug 5 epochs

learn.fit(epochs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.965</td>
#       <td>0.266</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.968</td>
#       <td>0.116</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.978</td>
#       <td>0.086</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.954</td>
#       <td>0.152</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.981</td>
#       <td>0.071</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.987</td>
#       <td>0.046</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.994</td>
#       <td>0.024</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.994</td>
#       <td>0.021</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.998</td>
#       <td>0.010</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.996</td>
#       <td>0.018</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# C:\ProgramData\Anaconda3\envs\invokeai\lib\site-packages\torch\nn\_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# C:\Users\rohit\AppData\Local\Temp\ipykernel_31708\2428293066.py:55: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   inverted_losses_for_epochs = torch.flip(torch.tensor(self.top_losses.clone().detach()[:n]), dims=(0,)).cpu()

# %%
learn = TrainLearner(model, dls, F.cross_entropy, lr=lr, cbs=cbs+xtra, opt_func=optim.AdamW)

# bs 256 + Mish + lr3e-2 + dropouts + aug 5 epochs

learn.fit(epochs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.968</td>
#       <td>0.257</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.984</td>
#       <td>0.065</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.982</td>
#       <td>0.072</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.985</td>
#       <td>0.054</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.984</td>
#       <td>0.058</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.992</td>
#       <td>0.032</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.996</td>
#       <td>0.018</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.995</td>
#       <td>0.018</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.999</td>
#       <td>0.007</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.996</td>
#       <td>0.017</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\rohit\AppData\Local\Temp\ipykernel_31708\2428293066.py:55: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   inverted_losses_for_epochs = torch.flip(torch.tensor(self.top_losses.clone().detach()[:n]), dims=(0,)).cpu()

# %%
learn = TrainLearner(model, dls, F.cross_entropy, lr=lr, cbs=cbs+xtra, opt_func=optim.AdamW)

# bs 256 + Mish + lr1e-2 + dropouts + aug 5 epochs

learn.fit(epochs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.967</td>
#       <td>0.302</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.980</td>
#       <td>0.106</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.984</td>
#       <td>0.080</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.986</td>
#       <td>0.063</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.986</td>
#       <td>0.056</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.993</td>
#       <td>0.027</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.997</td>
#       <td>0.017</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.996</td>
#       <td>0.019</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.999</td>
#       <td>0.009</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.996</td>
#       <td>0.018</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\rohit\AppData\Local\Temp\ipykernel_31708\2428293066.py:55: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   inverted_losses_for_epochs = torch.flip(torch.tensor(self.top_losses.clone().detach()[:n]), dims=(0,)).cpu()

# %% [markdown]
# ### TTA

# %%
# TTA

class CapturePreds(Callback):
    def before_fit(self, learn): 
        self.all_preds, self.all_targs = [], []
        
    def after_batch(self, learn):
        self.all_preds.append(to_cpu(learn.preds))
        self.all_targs.append(to_cpu(learn.batch[1]))

cp = CapturePreds()
learn.fit(1, train=False, cbs=cp)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.996</td>
#       <td>0.015</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>

# %%
def tfm_batch(b, tfm_x=fc.noop, tfm_y=fc.noop): 
    return tfm_x(b[0]), tfm_y(b[1])

# %%
cp2 = CapturePreds()
ttacb = BatchTransformCB(partial(tfm_batch, tfm_x=partial(TF.rotate, angle=5)), on_val=True)
learn.fit(1, train=False, cbs=[cp2, ttacb])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.993</td>
#       <td>0.028</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>

# %%
ap1 = torch.cat(cp.all_preds)
ap2 = torch.cat(cp2.all_preds)
at = torch.cat(cp.all_targs)
ap1.shape,ap2.shape
# Out:
# (torch.Size([10000, 10]), torch.Size([10000, 10]))

# %%
ap = torch.stack([ap1,ap2]).mean(0).argmax(1)

# %%
round((ap==at).float().mean().item(), 3)
# Out:
# 0.995

# %%
len(cp.all_preds[-1])
# Out:
# 16

# %%
ap1.shape
# Out:
# torch.Size([10000, 10])

# %%
at.shape
# Out:
# torch.Size([10000])

# %%
predictions = ap1.argmax(1)

targets = at

predictions == targets

wrongidxs = []
for i in range(len(predictions)):
    if predictions[i] != targets[i]:
        wrongidxs += [i]
        
wrongidxs    

wrongidxs = []
for i in range(len(predictions)):
    if predictions[i] != targets[i]:
        wrongidxs += [i]
        
wrongidxs    

len(wrongidxs)

valitems = list(iter(dls.valid))

len(valitems)

testimgs = torch.cat([valitems[i][0] for i in range(len(valitems))])

testimgs.shape

for idx in wrongidxs:
    print("Prediction:", predictions[idx].item(), "Target:", targets[idx].item())
    plt.imshow(testimgs[idx][0]);
    plt.show()

# %%
for idx in wrongidxs:
    print("Prediction:", predictions[idx].item(), "Target:", targets[idx].item())
    plt.imshow(testimgs[idx][0]);
    plt.show()
# Out:
# Prediction: 2 Target: 8
# Prediction: 7 Target: 2
# Prediction: 9 Target: 8
# Prediction: 5 Target: 6
# Prediction: 4 Target: 9
# Prediction: 5 Target: 9
# Prediction: 3 Target: 5
# Prediction: 3 Target: 8
# Prediction: 4 Target: 9
# Prediction: 3 Target: 5
# Prediction: 9 Target: 4
# Prediction: 1 Target: 6
# Prediction: 3 Target: 1
# Prediction: 3 Target: 5
# Prediction: 4 Target: 9
# Prediction: 3 Target: 5
# Prediction: 1 Target: 6
# Prediction: 0 Target: 8
# Prediction: 5 Target: 9
# Prediction: 9 Target: 7
# Prediction: 0 Target: 6
# Prediction: 2 Target: 6
# Prediction: 8 Target: 6
# Prediction: 8 Target: 7
# Prediction: 5 Target: 9
# Prediction: 0 Target: 6
# Prediction: 8 Target: 9
# Prediction: 0 Target: 6
# Prediction: 4 Target: 9
# Prediction: 2 Target: 7
# Prediction: 3 Target: 5
# Prediction: 7 Target: 9
# Prediction: 1 Target: 7
# Prediction: 7 Target: 0
# Prediction: 6 Target: 1
# Prediction: 2 Target: 7
# Prediction: 2 Target: 7
# Prediction: 6 Target: 5
